# %% [markdown]
# <a href="https://colab.research.google.com/github/AgainstEntropy/ECE-GY-6143-ML/blob/main/8_neural_net_demo_draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demo: Neural network for classification
# =======================================
#
# ------------------------------------------------------------------------
#
# *Fraida Fund*

# %% [markdown]
# *<small>Attribution: Some parts of this notebook are written by Sundeep Rangan, from his [IntroML GitHub repo](https://github.com/sdrangan/introml/).</small>*

# %% [markdown]
# We previously considered a general approach to learning a non-linear function of the input data: we can supply a non-linear data representation, by applying a non-linear transformation to the input data, or specifying a non-linear kernel. Then, the machine learning model learns from the transformed data.
#
# The power of neural networks is their ability to *learn* a “transformation”, rather than having to specify it ourselves! In this demo, we will see how.

# %% [markdown]
# Draw a classification problem
# -----------------------------

# %% [markdown]
# In the following cell, draw on the canvas to fill in the region of the feature space that should be part of the positive class.

# %%
#@title ### Colab drawing magic
# colab drawing magic via
# https://gist.github.com/korakot/8409b3feec20f159d8a50b0a811d3bca
from IPython.display import HTML, Image
from google.colab.output import eval_js
from base64 import b64decode

canvas_html = """
<canvas width=%d height=%d style='border:1px solid #000000;'></canvas>
<button>Finish</button>
<script>
var canvas = document.querySelector('canvas')
var ctx = canvas.getContext('2d')
ctx.lineWidth = %d
var button = document.querySelector('button')
var mouse = {x: 0, y: 0}

canvas.addEventListener('mousemove', function(e) {
  mouse.x = e.pageX - this.offsetLeft
  mouse.y = e.pageY - this.offsetTop
})
canvas.onmousedown = ()=>{
  ctx.beginPath()
  ctx.moveTo(mouse.x, mouse.y)
  canvas.addEventListener('mousemove', onPaint)
}
canvas.onmouseup = ()=>{
  canvas.removeEventListener('mousemove', onPaint)
}
var onPaint = ()=>{
  ctx.lineTo(mouse.x, mouse.y)
  ctx.stroke()
}

var data = new Promise(resolve=>{
  button.onclick = ()=>{
    resolve(canvas.toDataURL('image/png'))
  }
})
</script>
"""

def draw(filename='drawing.png', w=256, h=256, line_width=10):
  display(HTML(canvas_html % (w, h, line_width)))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)

# %%
draw()
# Out:
# <canvas width=256 height=256 style='border:1px solid #000000;'></canvas>
# <button>Finish</button>
# <script>
# var canvas = document.querySelector('canvas')
# var ctx = canvas.getContext('2d')
# ctx.lineWidth = 10
# var button = document.querySelector('button')
# var mouse = {x: 0, y: 0}
#
# canvas.addEventListener('mousemove', function(e) {
#   mouse.x = e.pageX - this.offsetLeft
#   mouse.y = e.pageY - this.offsetTop
# })
# canvas.onmousedown = ()=>{
#   ctx.beginPath()
#   ctx.moveTo(mouse.x, mouse.y)
#   canvas.addEventListener('mousemove', onPaint)
# }
# canvas.onmouseup = ()=>{
#   canvas.removeEventListener('mousemove', onPaint)
# }
# var onPaint = ()=>{
#   ctx.lineTo(mouse.x, mouse.y)
#   ctx.stroke()
# }
#
# var data = new Promise(resolve=>{
#   button.onclick = ()=>{
#     resolve(canvas.toDataURL('image/png'))
#   }
# })
# </script>

# %%
from PIL import Image
import numpy as np
im = Image.open("drawing.png")
np_im = np.array(im)
print(np_im.shape)
# Out:
# (256, 256, 4)

# %%
np_im_bw = np_im[:,:,3]

# %%
import matplotlib.pyplot as plt

plt.imshow(np_im_bw, cmap='binary');
plt.xlim(0,255);
plt.ylim(255,0);
plt.xlabel('x1');
plt.ylabel('x2');

# %% [markdown]
# Get training, validation, and test data
# ---------------------------------------

# %%
n_train = 5000
n_val   = 1000
n_test  = 10000

X_train = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_train), np.random.randint(0, np_im_bw.shape[1], size=n_train)))
y_train = np.rot90(np_im_bw, k=3)[X_train[:,0], X_train[:,1]]

X_train = X_train/255.0
y_train = y_train/255.0


X_val = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_val), np.random.randint(0, np_im_bw.shape[1], size=n_val)))
y_val = np.rot90(np_im_bw, k=3)[X_val[:,0], X_val[:,1]]

X_val = X_val/255.0
y_val = y_val/255.0


X_test = np.column_stack((np.random.randint(0, np_im_bw.shape[0], size=n_test), np.random.randint(0, np_im_bw.shape[1], size=n_test)))
y_test = np.rot90(np_im_bw, k=3)[X_test[:,0], X_test[:,1]]

X_test = X_test/255.0
y_test = y_test/255.0

# %%
import seaborn as sns

plt.scatter(x=X_train[:,0], y=X_train[:,1], c=y_train, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Training data");

# %% [markdown]
# Import Tensorflow + Keras
# -------------------------

# %% [markdown]
# For this demo, we will use Tensorflow with Keras to train and configure a neural network.
#
# Tensorflow is a powerful and widely-used platform for deep learning. However, Tensorflow is relatively low level and may be somewhat difficult to use as a starting point. We will use the `keras` package which acts as a high-level wrapper on top of tensorflow that allows you to quickly build and fit models.
#
# (A very popular alternative to Tensorflow for working with neural networks is PyTorch - you can read more about PyTorch [here](https://pytorch.org/).)

# %% [markdown]
# First we import Tensorflow.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.14.0

# %% [markdown]
# (There are two major versions of Tensorflow. Code that was written for TF1 often will not run with TF2. Fortunately, you can load either version in Colab, as described [here](https://colab.research.google.com/notebooks/tensorflow_version.ipynb).)

# %% [markdown]
# Create the neural network
# -------------------------

# %% [markdown]
# We will see if we can build a simple neural network classifier to learn the decision region that we drew above.

# %% [markdown]
# We first import some key sub-packages from `keras`.

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation

# %% [markdown]
# Next, we clear the session. This is not strictly necessary since we haven’t computed anything yet, but it is good practice if you are going to train multiple “temporary” models in a row - it frees up memory associated with models that are no longer in scope.

# %%
import tensorflow.keras.backend as K
K.clear_session()

# %% [markdown]
# Now we create a very simple network.
#
# The neural network has `nin=2` input units, corresponding to the two features.
#
# It has one hidden layer with `nh=4` hidden units. Each hidden unit will use a sigmoid activation function.
#
# There is `nout=1` output unit corresponding to the estimated class label. This unit will also have a sigmoid activation function.
#
# <small>Reference: [TF+keras activations](https://www.tensorflow.org/api_docs/python/tf/keras/activations).</small>

# %% [markdown]
# All of the layers are *dense* or *fully connected* layers, meaning that each node has a link to every node in the adjacent layers.
#
# <small>Reference: [Keras layers](https://keras.io/api/layers/)</small>

# %%
nin = 2  # dimension of input data
nh = 4  # number of hidden units
nout = 1  # number of outputs = 1 since this is binary
model = Sequential()
model.add(Dense(units=nh, input_shape=(nin,), activation='sigmoid', name='hidden'))
model.add(Dense(units=nout, activation='sigmoid', name='output'))

# %% [markdown]
# In our visualization of the network architechture, we will also add a *bias node* at each layer. This simplifies the computation of weights by adding an extra input whose value is always 1. The bias term then comes from the weight applied to that input.

# %%
#@title Visualize the network architecture

import networkx as nx

inputLayerSize  = nin
outputLayerSize = nout
hiddenLayerSize = nh


nodePos = {}
G=nx.Graph()
graphHeight = max(inputLayerSize, outputLayerSize, hiddenLayerSize)

# create nodes and note their positions
for n in range(inputLayerSize):
  nodePos['x'+str(n+1)]=(1, n)
  G.add_node('x'+str(n+1))
for n in range(outputLayerSize):
  nodePos['o'+str(n+1)]=(5, n)
  G.add_node('o'+str(n+1))
for n in range(hiddenLayerSize):
  nodePos['h'+str(n+1)]=(3, n)
  G.add_node('h'+str(n+1))

# add edges
for n in range(hiddenLayerSize):
  for m in range(inputLayerSize):
    G.add_edge('x' + str(m+1), 'h' + str(n+1))
  for m in range(outputLayerSize):
    G.add_edge('h' + str(n+1), 'o' + str(m+1))

# add bias nodes

nodePos['xb']=(1, inputLayerSize)
G.add_node('xb')
for n in range(hiddenLayerSize):
  G.add_edge('xb', 'h' + str(n+1))

nodePos['hb']=(3, hiddenLayerSize)
G.add_node('hb')
for n in range(outputLayerSize):
  G.add_edge('hb', 'o' + str(n+1))

nx.draw_networkx(G, pos=nodePos,
              node_size=1000, node_color='pink')
plt.axis('off');
plt.margins(0.2, 0.2);

# %% [markdown]
# Each node in the neural network applies its activation function to the weighted sum of its inputs, then passes that as output to the nodes in the next layer.
#
# The neural network needs to learn a weight for each link in the image above (including the weights for the bias nodes).

# %% [markdown]
# Keras has a nice command for summarizing the network architecture:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 4)                 12
#
#  output (Dense)              (None, 1)                 5
#
# =================================================================
# Total params: 17 (68.00 Byte)
# Trainable params: 17 (68.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next, we have to select an optimizer and a loss function.
#
# Since this is a binary classification problem, we select the `binary_crossentropy` loss.
#
# We will also choose an optimizer (Adam) and a learning rate of `learning_rate=0.01`.
#
# We also set the `metrics` that we wish to track during the optimization. In this case, we select `accuracy` on the training set.
#
# Finally, before training, we must `compile` the model.
#
# <small>Reference: [TF+keras loss functions](https://www.tensorflow.org/api_docs/python/tf/keras/losses), [Keras optimizers](https://keras.io/api/optimizers/)</small>

# %%
from tensorflow.keras import optimizers

opt = optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train the neural network
# ------------------------

# %% [markdown]
# Keras provides a simple method `fit` to run the optimization. You simply specify the number of epochs and the batch size.
#
# We will also pass it some `validation_data` - it will also compute the loss and accuracy on the validation data at each epoch.
#
# (During one epoch, we run as many iterations of mini-batch stochastic gradient descent as it takes to sample all the training data, without replacement.)

# %%
hist = model.fit(X_train, y_train, epochs=100, batch_size=24, validation_data=(X_val,y_val))
# Out:
# Epoch 1/100
# 209/209 [==============================] - 1s 2ms/step - loss: 0.4609 - accuracy: 0.8312 - val_loss: 0.4360 - val_accuracy: 0.8410
# Epoch 2/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4527 - accuracy: 0.8312 - val_loss: 0.4358 - val_accuracy: 0.8410
# Epoch 3/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4513 - accuracy: 0.8312 - val_loss: 0.4348 - val_accuracy: 0.8410
# Epoch 4/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.8312 - val_loss: 0.4346 - val_accuracy: 0.8410
# Epoch 5/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4503 - accuracy: 0.8312 - val_loss: 0.4362 - val_accuracy: 0.8410
# Epoch 6/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.8312 - val_loss: 0.4357 - val_accuracy: 0.8410
# Epoch 7/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4497 - accuracy: 0.8312 - val_loss: 0.4345 - val_accuracy: 0.8410
# Epoch 8/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8312 - val_loss: 0.4335 - val_accuracy: 0.8410
# Epoch 9/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4491 - accuracy: 0.8312 - val_loss: 0.4331 - val_accuracy: 0.8410
# Epoch 10/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4488 - accuracy: 0.8312 - val_loss: 0.4358 - val_accuracy: 0.8410
# Epoch 11/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4481 - accuracy: 0.8312 - val_loss: 0.4325 - val_accuracy: 0.8410
# Epoch 12/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4472 - accuracy: 0.8312 - val_loss: 0.4343 - val_accuracy: 0.8410
# Epoch 13/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4458 - accuracy: 0.8312 - val_loss: 0.4302 - val_accuracy: 0.8410
# Epoch 14/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.8312 - val_loss: 0.4283 - val_accuracy: 0.8410
# Epoch 15/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.8312 - val_loss: 0.4235 - val_accuracy: 0.8410
# Epoch 16/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8312 - val_loss: 0.4208 - val_accuracy: 0.8410
# Epoch 17/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4303 - accuracy: 0.8312 - val_loss: 0.4161 - val_accuracy: 0.8410
# Epoch 18/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4263 - accuracy: 0.8312 - val_loss: 0.4125 - val_accuracy: 0.8410
# Epoch 19/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8312 - val_loss: 0.4087 - val_accuracy: 0.8410
# Epoch 20/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8312 - val_loss: 0.4045 - val_accuracy: 0.8410
# Epoch 21/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8312 - val_loss: 0.4029 - val_accuracy: 0.8410
# Epoch 22/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8312 - val_loss: 0.3989 - val_accuracy: 0.8410
# Epoch 23/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8312 - val_loss: 0.3934 - val_accuracy: 0.8410
# Epoch 24/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8312 - val_loss: 0.3887 - val_accuracy: 0.8410
# Epoch 25/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8312 - val_loss: 0.3879 - val_accuracy: 0.8410
# Epoch 26/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8312 - val_loss: 0.3825 - val_accuracy: 0.8410
# Epoch 27/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8312 - val_loss: 0.3791 - val_accuracy: 0.8410
# Epoch 28/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8312 - val_loss: 0.3731 - val_accuracy: 0.8410
# Epoch 29/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3833 - accuracy: 0.8312 - val_loss: 0.3689 - val_accuracy: 0.8410
# Epoch 30/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8312 - val_loss: 0.3662 - val_accuracy: 0.8410
# Epoch 31/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3748 - accuracy: 0.8312 - val_loss: 0.3634 - val_accuracy: 0.8410
# Epoch 32/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3707 - accuracy: 0.8312 - val_loss: 0.3588 - val_accuracy: 0.8410
# Epoch 33/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8312 - val_loss: 0.3573 - val_accuracy: 0.8410
# Epoch 34/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3651 - accuracy: 0.8312 - val_loss: 0.3582 - val_accuracy: 0.8410
# Epoch 35/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8312 - val_loss: 0.3570 - val_accuracy: 0.8410
# Epoch 36/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8312 - val_loss: 0.3499 - val_accuracy: 0.8410
# Epoch 37/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8308 - val_loss: 0.3493 - val_accuracy: 0.8410
# Epoch 38/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3575 - accuracy: 0.8312 - val_loss: 0.3478 - val_accuracy: 0.8410
# Epoch 39/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8282 - val_loss: 0.3468 - val_accuracy: 0.8410
# Epoch 40/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8278 - val_loss: 0.3505 - val_accuracy: 0.8110
# Epoch 41/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8202 - val_loss: 0.3449 - val_accuracy: 0.8410
# Epoch 42/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3534 - accuracy: 0.8216 - val_loss: 0.3444 - val_accuracy: 0.8310
# Epoch 43/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8188 - val_loss: 0.3465 - val_accuracy: 0.8090
# Epoch 44/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8136 - val_loss: 0.3444 - val_accuracy: 0.8120
# Epoch 45/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3504 - accuracy: 0.8154 - val_loss: 0.3518 - val_accuracy: 0.7770
# Epoch 46/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8076 - val_loss: 0.3412 - val_accuracy: 0.8410
# Epoch 47/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8096 - val_loss: 0.3426 - val_accuracy: 0.8080
# Epoch 48/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3484 - accuracy: 0.8108 - val_loss: 0.3434 - val_accuracy: 0.7980
# Epoch 49/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3477 - accuracy: 0.8068 - val_loss: 0.3407 - val_accuracy: 0.8120
# Epoch 50/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3469 - accuracy: 0.8042 - val_loss: 0.3390 - val_accuracy: 0.8410
# Epoch 51/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8064 - val_loss: 0.3393 - val_accuracy: 0.8410
# Epoch 52/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3457 - accuracy: 0.8104 - val_loss: 0.3395 - val_accuracy: 0.8100
# Epoch 53/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8022 - val_loss: 0.3401 - val_accuracy: 0.7990
# Epoch 54/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.7998 - val_loss: 0.3382 - val_accuracy: 0.8070
# Epoch 55/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.7978 - val_loss: 0.3366 - val_accuracy: 0.8220
# Epoch 56/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8026 - val_loss: 0.3371 - val_accuracy: 0.8090
# Epoch 57/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8054 - val_loss: 0.3353 - val_accuracy: 0.8080
# Epoch 58/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3415 - accuracy: 0.8060 - val_loss: 0.3388 - val_accuracy: 0.7830
# Epoch 59/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3409 - accuracy: 0.7942 - val_loss: 0.3341 - val_accuracy: 0.8130
# Epoch 60/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.7982 - val_loss: 0.3334 - val_accuracy: 0.8020
# Epoch 61/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.7988 - val_loss: 0.3353 - val_accuracy: 0.7930
# Epoch 62/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.7942 - val_loss: 0.3329 - val_accuracy: 0.8100
# Epoch 63/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.7934 - val_loss: 0.3309 - val_accuracy: 0.8090
# Epoch 64/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3368 - accuracy: 0.8016 - val_loss: 0.3309 - val_accuracy: 0.8080
# Epoch 65/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.7936 - val_loss: 0.3292 - val_accuracy: 0.8060
# Epoch 66/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3348 - accuracy: 0.7928 - val_loss: 0.3284 - val_accuracy: 0.8040
# Epoch 67/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3335 - accuracy: 0.7890 - val_loss: 0.3305 - val_accuracy: 0.7840
# Epoch 68/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.7912 - val_loss: 0.3280 - val_accuracy: 0.7920
# Epoch 69/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.7922 - val_loss: 0.3286 - val_accuracy: 0.7780
# Epoch 70/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3313 - accuracy: 0.7892 - val_loss: 0.3291 - val_accuracy: 0.7730
# Epoch 71/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3311 - accuracy: 0.7886 - val_loss: 0.3278 - val_accuracy: 0.7810
# Epoch 72/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3299 - accuracy: 0.7840 - val_loss: 0.3264 - val_accuracy: 0.7780
# Epoch 73/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.7806 - val_loss: 0.3248 - val_accuracy: 0.7880
# Epoch 74/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3280 - accuracy: 0.7822 - val_loss: 0.3231 - val_accuracy: 0.8060
# Epoch 75/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3273 - accuracy: 0.7886 - val_loss: 0.3255 - val_accuracy: 0.7750
# Epoch 76/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3266 - accuracy: 0.7816 - val_loss: 0.3247 - val_accuracy: 0.7700
# Epoch 77/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.7774 - val_loss: 0.3211 - val_accuracy: 0.8010
# Epoch 78/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 0.7830 - val_loss: 0.3221 - val_accuracy: 0.7830
# Epoch 79/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.7850 - val_loss: 0.3227 - val_accuracy: 0.7710
# Epoch 80/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.7722 - val_loss: 0.3202 - val_accuracy: 0.7910
# Epoch 81/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.7834 - val_loss: 0.3234 - val_accuracy: 0.7610
# Epoch 82/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3226 - accuracy: 0.7800 - val_loss: 0.3192 - val_accuracy: 0.7820
# Epoch 83/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3219 - accuracy: 0.7822 - val_loss: 0.3193 - val_accuracy: 0.7780
# Epoch 84/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3216 - accuracy: 0.7762 - val_loss: 0.3192 - val_accuracy: 0.7800
# Epoch 85/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3208 - accuracy: 0.7788 - val_loss: 0.3192 - val_accuracy: 0.7770
# Epoch 86/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.7850 - val_loss: 0.3196 - val_accuracy: 0.7640
# Epoch 87/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3200 - accuracy: 0.7700 - val_loss: 0.3161 - val_accuracy: 0.7840
# Epoch 88/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.7750 - val_loss: 0.3157 - val_accuracy: 0.7860
# Epoch 89/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3189 - accuracy: 0.7790 - val_loss: 0.3154 - val_accuracy: 0.7850
# Epoch 90/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.7742 - val_loss: 0.3149 - val_accuracy: 0.7820
# Epoch 91/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3176 - accuracy: 0.7712 - val_loss: 0.3139 - val_accuracy: 0.7950
# Epoch 92/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3171 - accuracy: 0.7740 - val_loss: 0.3134 - val_accuracy: 0.7970
# Epoch 93/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3162 - accuracy: 0.7848 - val_loss: 0.3161 - val_accuracy: 0.7600
# Epoch 94/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.7664 - val_loss: 0.3135 - val_accuracy: 0.7720
# Epoch 95/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3155 - accuracy: 0.7746 - val_loss: 0.3136 - val_accuracy: 0.7680
# Epoch 96/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3150 - accuracy: 0.7712 - val_loss: 0.3116 - val_accuracy: 0.7820
# Epoch 97/100
# 209/209 [==============================] - 0s 1ms/step - loss: 0.3148 - accuracy: 0.7728 - val_loss: 0.3122 - val_accuracy: 0.7780
# Epoch 98/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 0.7780 - val_loss: 0.3118 - val_accuracy: 0.7690
# Epoch 99/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3141 - accuracy: 0.7752 - val_loss: 0.3123 - val_accuracy: 0.7680
# Epoch 100/100
# 209/209 [==============================] - 0s 2ms/step - loss: 0.3136 - accuracy: 0.7734 - val_loss: 0.3115 - val_accuracy: 0.7730

# %% [markdown]
# If you run the `fit` cell more than once, it will update the fit by running more gradient descent iterations - it won’t start again from the beginning. However, it *will* overwrite your previous model “history” (i.e. the loss and accuracy per epoch from the last call to `fit`).

# %% [markdown]
# Visualize output of network
# ---------------------------

# %% [markdown]
# To see the classification rule our neural network learned, we can plot the predicted class probability over the input space.
#
# We can also plot the response in the each of the hidden units.
#
# Each of the hidden units produces one linear decision region. The final nonlinear region is then formed by taking a weighted combination of these regions.

# %%
#@title Visualize output of each unit

# Prepare coordinate grid
n_plot = 256
xx1, xx2 = np.meshgrid(np.arange(0, n_plot, 1),np.arange(0, n_plot, 1))
X_grid = np.hstack((xx1.reshape(n_plot**2,1), xx2.reshape(n_plot**2,1)))
X_grid = X_grid/(n_plot-1.0)

# Get the response in the hidden units
layer_hid = model.get_layer('hidden')
model1 = Model(inputs=model.input,
               outputs=layer_hid.output)
zhid_plot = model1.predict(X_grid)
zhid_plot = zhid_plot.reshape((n_plot,n_plot,nh))

# Get the weights in the output layer
layer_out = model.get_layer('output')
Wo, bo = layer_out.get_weights()

# Get the response in the output layer
yplot = model.predict(X_grid)
yplot_mat = yplot[:,0].reshape((n_plot, n_plot))

# Plot the output layer
fig = plt.figure(figsize=(15, 6))
plt.subplot(1,nh+1,1)
plt.imshow(np.flipud((yplot_mat.reshape(n_plot, n_plot))), cmap='binary');
plt.xlim(0, n_plot);
plt.ylim(n_plot,0);
plt.xticks([]);
plt.yticks([]);
plt.title("Output")
plt.xlim(0,n_plot);
plt.ylim(n_plot, 0);

# Plot the hidden layers
for i in range(nh):

    plt.subplot(1,nh+1,i+1+1)
    zhid_ploti = (zhid_plot[:,:,i])
    im = plt.imshow(zhid_ploti, vmin=0, vmax=1, cmap='binary')
    im = plt.imshow(np.flipud((zhid_ploti)), cmap='binary');
    plt.xticks([])
    plt.yticks([])
    plt.title('h{0:d}, Wo={1:4.2f}'.format(i+1,Wo[i,0]))
    plt.xlim(0,n_plot);
    plt.ylim(n_plot,0);

fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.9, 0.30, 0.05, 0.4])
fig.colorbar(im, cax=cbar_ax);
# Out:
# 2048/2048 [==============================] - 2s 1ms/step
# 2048/2048 [==============================] - 2s 874us/step

# %% [markdown]
# We can also check all of the parameters learned by the network:

# %%
layer_hid = model.get_layer('hidden')
Wh, bh = layer_hid.get_weights()
print('Wh=')
print(Wh)
print('bh=')
print(bh)

layer_out = model.get_layer('output')
Wo, bo = layer_out.get_weights()
print('Wo=')
print(Wo)
print('bo=')
print(bo)
# Out:
# Wh=
# [[-19.788908    5.3431473  -5.5854855   7.2436943]
#  [ -7.855287  -18.384907   10.3970995   3.4448798]]
# bh=
# [ 4.5498047 -2.9053648 -7.8075843 -9.397446 ]
# Wo=
# [[-16.997175]
#  [-13.2456  ]
#  [-13.007302]
#  [-11.183208]]
# bo=
# [0.25622848]

# %% [markdown]
# And, we can visualize the training progress vs. epoch:

# %%
import seaborn as sns

plt.figure(figsize=(7,3))

plt.subplot(1,2,1)
train_acc = hist.history['accuracy'];
val_acc = hist.history['val_accuracy'];

nepochs = len(train_acc);
sns.lineplot(x=np.arange(1,nepochs+1), y=train_acc, label='Training accuracy');
sns.lineplot(x=np.arange(1,nepochs+1), y=val_acc, label='Validation accuracy');
plt.xlabel('Epoch');
plt.ylabel('Accuracy');

plt.subplot(1,2,2)
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
sns.lineplot(x=np.arange(1,nepochs+1), y=train_loss, label='Training loss');
sns.lineplot(x=np.arange(1,nepochs+1), y=val_loss, label='Validation loss');
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.tight_layout()

# %% [markdown]
# Measure performance on test set
# -------------------------------

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).astype(int)
y_pred = y_pred.squeeze()
# Out:
# 313/313 [==============================] - 0s 926us/step

# %%
np.mean((y_pred == y_test).astype(int))
# Out:
# 0.7667

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(x=X_test[:,0], y=X_test[:,1], c=y_pred, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Predictions for test data");

plt.subplot(1,2,2)
plt.scatter(x=X_test[:,0], y=X_test[:,1], c=y_test, cmap='binary', edgecolors= "gray")
plt.xlabel("x1");
plt.ylabel("x2");
plt.title("Actual test data");

# %% [markdown]
# Things to try
# -------------
#
# -   What happens if we use `linear` activations, instead of sigmoid?
# -   When do we need to use a large number of hidden units?
# -   Try to adjust the learning rate and batch size. What is the effect?
# -   What should you do if you want to train the model for a few more epochs? (What happens to your history when you do that?)
# -   What should you do if you want to change the model architecture and train it from scratch?
