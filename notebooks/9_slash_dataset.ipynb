# %% [markdown]
# <a href="https://colab.research.google.com/github/AgainstEntropy/ECE-GY-6143-ML/blob/main/9_slash_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demo: Convolutional neural networks on the “slash” dataset
# ==========================================================
#
# *Fraida Fund*

# %% [markdown]
# In this demo, we’ll look at an example of a task that is difficult for “classical” machine learning models, and difficult for fully connected neural networks, but easy for convolutional neural networks.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import keras
import numpy as np
import pandas as pd
import scipy

from sklearn.model_selection import train_test_split
from sklearn import ensemble, neighbors, linear_model, svm

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Activation, Conv2D, Flatten, BatchNormalization, InputLayer, AvgPool2D, MaxPool2D, GlobalAvgPool2D
import tensorflow.keras.backend as K
from keras.utils import plot_model

# %% [markdown]
# The slash dataset
# -----------------
#
# The “slash” dataset, developed by [Sophie Searcy](https://soph.info/slash-data), is a set of images, each of which includes a “slash” on a background of random noise. The data is divided into two classes according to whether the slash is downward facing or upward facing.

# %%
def gen_example(size=20, label=0):

    max_s_pattern = int(size // 4)
    s_pattern = 4
    pattern = 1- np.eye(s_pattern)
    if label:
        pattern = pattern[:, ::-1]
    ex = np.ones((size,size))
    point_loc = np.random.randint(0, size - s_pattern + 1,
                                  size=(2, ))  # random x,y point
    ex[point_loc[0]:point_loc[0] + s_pattern, point_loc[1]:point_loc[1] +
       s_pattern] = pattern  # set point to
    ex = ex + .5*(np.random.rand(size, size) - .5)
    np.clip(ex,0.,1., out=ex)
    return ex

# %%
examples = []

n_side = 30
n_ex = 500 #number of examples in each class

for i in range(n_ex):
    examples.append(gen_example(size=n_side, label=0))
    examples.append(gen_example(size=n_side, label=1))

y = np.array([0,1]*n_ex)
x = np.stack(examples)

# %%
plt.figure(figsize=(18,4))

n_print = 10 # number of examples to show

ex_indices = np.random.choice(len(y), n_print, replace=False)
for i, index in enumerate(ex_indices):
    plt.subplot(1, n_print, i+1, )
    plt.imshow(x[index,...], cmap='gray')
    plt.title(f"y = {y[index]}")

# %% [markdown]
# We’l prepare training and test data in two formats:
#
# -   “flat” for traditional ML models and fully connected neural networks, which don’t care about the spatial arrangement of the features.
# -   “image” for convolutional neural networks.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.25)

x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

x_train_img = x_train[...,np.newaxis]
x_test_img = x_test[...,np.newaxis]

# %%
print("Flat data shape:  ", x_train_flat.shape)
print("Image data shape: ", x_train_img.shape)
# Out:
# Flat data shape:   (750, 900)
# Image data shape:  (750, 30, 30, 1)

# %% [markdown]
# The feature data is in the range 0 to 1:

# %%
x.min(), x.max()

# %% [markdown]
# Train logistic regression, random forest, KNN, SVM models
# ---------------------------------------------------------

# %% [markdown]
# Next, we’ll try to train some classic ML models on this dataset.

# %%
models = {
    "Logistic\n Regression": linear_model.LogisticRegression(),
    "KNN-1": neighbors.KNeighborsClassifier(n_neighbors=1),
    "KNN-3": neighbors.KNeighborsClassifier(n_neighbors=3),
    "Random\n Forest": ensemble.RandomForestClassifier(n_estimators=100),
    "SVM -\n Linear": svm.SVC(kernel="linear"),
    "SVM -\n RBF kernel": svm.SVC(kernel="rbf")
}

# %%
results = []

for model_name in models.keys():
    model = models[model_name]
    model.fit(x_train_flat, y_train)

    train_score = model.score(x_train_flat, y_train)
    test_score = model.score(x_test_flat, y_test)

    results.append({"model": model_name, "train_score": train_score, "test_score": test_score})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
results_df = pd.DataFrame(results)

plt.figure(figsize =(10,10));

plt.subplot(2,1,1)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['train_score']);
plt.ylim(0,1);
plt.xlabel("")

plt.subplot(2,1,2)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['test_score']);
plt.ylim(0,1);

# %% [markdown]
# Are these the results we expected? Why or why not?

# %% [markdown]
# Do *any* of these models do a good job of learning whether a slash is forward-facing or backward-facing?

# %% [markdown]
# Train a fully connected neural network
# --------------------------------------

# %%
nin = x_train_flat.shape[1]
nh1 = 64
nh2 = 64
nh3 = 64
nout = 1
model_fc = Sequential()
model_fc.add(Dense(units=nh1, input_shape=(nin,), activation='relu', name='hidden1'))
model_fc.add(Dense(units=nh2, input_shape=(nh1,), activation='relu', name='hidden2'))
model_fc.add(Dense(units=nh3, input_shape=(nh2,), activation='relu', name='hidden3'))
model_fc.add(Dense(units=nout, activation='sigmoid', name='output'))

model_fc.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_fc.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden1 (Dense)             (None, 64)                57664
#
#  hidden2 (Dense)             (None, 64)                4160
#
#  hidden3 (Dense)             (None, 64)                4160
#
#  output (Dense)              (None, 1)                 65
#
# =================================================================
# Total params: 66049 (258.00 KB)
# Trainable params: 66049 (258.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist = model_fc.fit(x_train_flat, y_train, epochs=100,
     validation_split=0.25,  callbacks=[
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=2, verbose=1),
        keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1)
    ])
# Out:
# Epoch 1/100
# 18/18 [==============================] - 3s 42ms/step - loss: 0.7109 - accuracy: 0.4804 - val_loss: 0.6934 - val_accuracy: 0.4787 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.6953 - accuracy: 0.5107 - val_loss: 0.7022 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.4911
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 18/18 [==============================] - 0s 16ms/step - loss: 0.6989 - accuracy: 0.4911 - val_loss: 0.6961 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.7029 - accuracy: 0.4769 - val_loss: 0.6933 - val_accuracy: 0.5106 - lr: 5.0000e-04
# Epoch 5/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.6958 - accuracy: 0.5089 - val_loss: 0.6941 - val_accuracy: 0.4894 - lr: 5.0000e-04
# Epoch 6/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6963 - accuracy: 0.5036 - val_loss: 0.6930 - val_accuracy: 0.5106 - lr: 5.0000e-04
# Epoch 7/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6964 - accuracy: 0.4680 - val_loss: 0.6931 - val_accuracy: 0.4734 - lr: 5.0000e-04
# Epoch 8/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6945 - accuracy: 0.5104
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6940 - accuracy: 0.5089 - val_loss: 0.6962 - val_accuracy: 0.5106 - lr: 5.0000e-04
# Epoch 9/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.7010 - accuracy: 0.4626 - val_loss: 0.6944 - val_accuracy: 0.4894 - lr: 2.5000e-04
# Epoch 10/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6967 - accuracy: 0.4779
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6967 - accuracy: 0.4769 - val_loss: 0.6932 - val_accuracy: 0.5160 - lr: 2.5000e-04
# Epoch 11/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6937 - accuracy: 0.4982 - val_loss: 0.6953 - val_accuracy: 0.4894 - lr: 1.2500e-04
# Epoch 12/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.6933 - accuracy: 0.5098
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.5053 - val_loss: 0.6936 - val_accuracy: 0.4947 - lr: 1.2500e-04
# Epoch 13/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6940 - accuracy: 0.4680 - val_loss: 0.6933 - val_accuracy: 0.4840 - lr: 6.2500e-05
# Epoch 14/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6930 - accuracy: 0.5042
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6938 - accuracy: 0.4875 - val_loss: 0.6940 - val_accuracy: 0.4894 - lr: 6.2500e-05
# Epoch 15/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5071 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 3.1250e-05
# Epoch 16/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6931 - accuracy: 0.5018
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.4982 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 3.1250e-05
# Epoch 17/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5160 - val_loss: 0.6935 - val_accuracy: 0.4787 - lr: 1.5625e-05
# Epoch 18/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.6929 - accuracy: 0.5188
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5178 - val_loss: 0.6934 - val_accuracy: 0.4840 - lr: 1.5625e-05
# Epoch 19/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5374 - val_loss: 0.6934 - val_accuracy: 0.4787 - lr: 7.8125e-06
# Epoch 20/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.6931 - accuracy: 0.5156
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5231 - val_loss: 0.6935 - val_accuracy: 0.4787 - lr: 7.8125e-06
# Epoch 21/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5089 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 3.9063e-06
# Epoch 22/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.6927 - accuracy: 0.5117
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5107 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 3.9063e-06
# Epoch 23/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5142 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 1.9531e-06
# Epoch 24/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5089
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5089 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 1.9531e-06
# Epoch 25/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6928 - accuracy: 0.5160 - val_loss: 0.6935 - val_accuracy: 0.4894 - lr: 9.7656e-07
# Epoch 26/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6928 - accuracy: 0.5202
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Restoring model weights from the end of the best epoch: 6.
# 18/18 [==============================] - 0s 7ms/step - loss: 0.6928 - accuracy: 0.5142 - val_loss: 0.6935 - val_accuracy: 0.4840 - lr: 9.7656e-07
# Epoch 26: early stopping

# %%
train_score = model_fc.evaluate(x_train_flat, y_train)[1]
test_score = model_fc.evaluate(x_test_flat, y_test)[1]
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.5000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.5000

# %%
results.append({"model": 'FC Neural Net', "train_score": train_score, "test_score": test_score})

# %%
results_df = pd.DataFrame(results)

plt.figure(figsize =(11,10));

plt.subplot(2,1,1)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['train_score']);
plt.ylim(0,1);
plt.xlabel("")

plt.subplot(2,1,2)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['test_score']);
plt.ylim(0,1);

# %% [markdown]
# Train a convolutional neural network
# ------------------------------------

# %%
filters = 10
model_conv = Sequential()
model_conv.add(InputLayer(input_shape=x_train_img.shape[1:]))
model_conv.add(Conv2D(filters, kernel_size=3, padding="same", activation="relu", use_bias=False ))
model_conv.add(MaxPool2D(pool_size=(2, 2)))
model_conv.add(BatchNormalization())
model_conv.add(Conv2D(filters, kernel_size=3, padding="same", activation="relu", use_bias=False ))
model_conv.add(GlobalAvgPool2D())
model_conv.add(Dense(1, activation="sigmoid"))

model_conv.summary()

model_conv.compile("adam", loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 10)        90
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 10)        0
#  D)
#
#  batch_normalization (Batch  (None, 15, 15, 10)        40
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 10)        900
#
#  global_average_pooling2d (  (None, 10)                0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1041 (4.07 KB)
# Trainable params: 1021 (3.99 KB)
# Non-trainable params: 20 (80.00 Byte)
# _________________________________________________________________

# %%
hist = model_conv.fit(x_train_img, y_train, epochs=100,
     validation_split=0.25,  callbacks=[
        keras.callbacks.ReduceLROnPlateau(factor=.5, patience=2, verbose=1),
        keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, verbose=1)
    ])

train_score = model_conv.evaluate(x_train_img, y_train)[1]
test_score = model_conv.evaluate(x_test_img, y_test)[1]
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 55ms/step - loss: 0.6947 - accuracy: 0.5036 - val_loss: 0.6934 - val_accuracy: 0.4894 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 0s 25ms/step - loss: 0.6871 - accuracy: 0.5890 - val_loss: 0.6927 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.6800 - accuracy: 0.7473 - val_loss: 0.6922 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.6688 - accuracy: 0.9235 - val_loss: 0.6915 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 5/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.6513 - accuracy: 0.9964 - val_loss: 0.6901 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 6/100
# 18/18 [==============================] - 0s 21ms/step - loss: 0.6188 - accuracy: 0.9982 - val_loss: 0.6885 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 7/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.5671 - accuracy: 1.0000 - val_loss: 0.6878 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 8/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.4934 - accuracy: 1.0000 - val_loss: 0.6840 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 9/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.4069 - accuracy: 1.0000 - val_loss: 0.6802 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 10/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.3160 - accuracy: 1.0000 - val_loss: 0.6778 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 11/100
# 18/18 [==============================] - 0s 21ms/step - loss: 0.2359 - accuracy: 1.0000 - val_loss: 0.6688 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 12/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1674 - accuracy: 1.0000 - val_loss: 0.6536 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 13/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.1214 - accuracy: 1.0000 - val_loss: 0.6225 - val_accuracy: 0.5106 - lr: 0.0010
# Epoch 14/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.9734 - lr: 0.0010
# Epoch 15/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.5324 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/100
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0560 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.4547 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.4101 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.3662 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.3262 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.2880 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2439 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0497 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 33/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/100
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 35/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 36/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 37/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 38/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 39/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 40/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 41/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 42/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 43/100
# 18/18 [==============================] - 1s 31ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 44/100
# 18/18 [==============================] - 1s 34ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 45/100
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 46/100
# 18/18 [==============================] - 1s 38ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 47/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 48/100
# 18/18 [==============================] - 1s 42ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 49/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 50/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 51/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 52/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 53/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 54/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 55/100
# 18/18 [==============================] - 1s 30ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 56/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 57/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 58/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 59/100
# 18/18 [==============================] - 1s 39ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 60/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 61/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 62/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 63/100
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 64/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 2.5000e-04
# Epoch 65/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 66/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 66: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 67/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 68/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 69/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 70/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 71/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 72/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 73/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 73: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 74/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 75/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 7.8125e-06
# Epoch 76/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 77/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 3.9063e-06
# Epoch 78/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 79/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 79: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.9531e-06
# Epoch 80/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 81/100
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 81: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 9.7656e-07
# Epoch 82/100
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 83/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 83: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 18/18 [==============================] - 0s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 4.8828e-07
# Epoch 84/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 85/100
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 2.4414e-07
# Epoch 86/100
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 87/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 18/18 [==============================] - 0s 28ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.2207e-07
# Epoch 88/100
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 6.1035e-08
# Epoch 89/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 18/18 [==============================] - 1s 36ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 6.1035e-08
# Epoch 90/100
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 3.0518e-08
# Epoch 91/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 18/18 [==============================] - 1s 40ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 3.0518e-08
# Epoch 92/100
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.5259e-08
# Epoch 93/100
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 93: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Restoring model weights from the end of the best epoch: 73.
# 18/18 [==============================] - 1s 35ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.5259e-08
# Epoch 93: early stopping
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000

# %%
results.append({"model": 'ConvNet', "train_score": train_score, "test_score": test_score})

# %%
results_df = pd.DataFrame(results)

plt.figure(figsize =(12,10));

plt.subplot(2,1,1)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['train_score']);
plt.ylim(0,1);
plt.xlabel("")

plt.subplot(2,1,2)
sns.barplot(x=results_df.sort_values('test_score')['model'], y=results_df.sort_values('test_score')['test_score']);
plt.ylim(0,1);

# %% [markdown]
# Using the same model on different slashes
# -----------------------------------------

# %% [markdown]
# Not only did our convolutional network learn forward and backward slashes - it can even generalize to slightly different forward and backward slashes.
#
# Let’s generate data with heavier background noise, and longer slashes:

# %%
noise_scale = 0.65
s_pattern = 15
def gen_example_different(size=20, label=0):

    max_s_pattern = int(size // 4)
    pattern = 1- np.eye(s_pattern)
    if label:
        pattern = pattern[:, ::-1]
    ex = np.ones((size,size))
    point_loc = np.random.randint(0, size - s_pattern + 1,
                                  size=(2, ))  # random x,y point
    ex[point_loc[0]:point_loc[0] + s_pattern, point_loc[1]:point_loc[1] +
       s_pattern] = pattern  # set point to
    ex = ex + noise_scale*(np.random.rand(size, size) - .5)
    np.clip(ex,0.,1., out=ex)
    return ex

examples = []

n_side = 30
n_ex = 50 #number of examples in each class

for i in range(n_ex):
    examples.append(gen_example_different(size=n_side, label=0))
    examples.append(gen_example_different(size=n_side, label=1))

y_new = np.array([0,1]*n_ex)
x_new = np.stack(examples)

plt.figure(figsize=(18,4))

n_print = 10 # number of examples to show

ex_indices = np.random.choice(len(y_new), n_print, replace=False)
for i, index in enumerate(ex_indices):
    plt.subplot(1, n_print, i+1, )
    plt.imshow(x_new[index,...], cmap='gray')
    plt.title(f"y = {y_new[index]}")

# %%
plt.figure(figsize=(18,4))

for i, index in enumerate(ex_indices):
    plt.subplot(1, n_print, i+1, )
    plt.imshow(x_new[index,...], cmap='gray')
    plt.title("yhat =  %0.2f" % model_conv.predict(x_new[index].reshape((1,30,30,1))))
# Out:
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
new_test_score = model_conv.evaluate(x_new[...,np.newaxis], y_new)[1]
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 9.1358e-12 - accuracy: 1.0000

# %% [markdown]
# What about forward and backward slashes at different angles?

# %%
max_rot = 10
def gen_example_rotated(size=20, label=0):

    max_s_pattern = int(size // 4)
    s_pattern = 15
    pattern = 1- np.eye(s_pattern)
    if label:
        pattern = pattern[:, ::-1]
    ex = np.ones((size,size))
    point_loc = np.random.randint(0, size - s_pattern + 1,   size=(2, ))
    ex[point_loc[0]:point_loc[0] + s_pattern, point_loc[1]:point_loc[1] + s_pattern] = pattern
    rot_angle = np.random.uniform(-max_rot, max_rot)
    ex = scipy.ndimage.rotate(ex, angle=rot_angle, cval=1, reshape = False)
    ex = ex + noise_scale*(np.random.rand(size, size) - .5)

    np.clip(ex,0.,1., out=ex)
    return ex

examples = []

n_side = 30
n_ex = 50 #number of examples in each class

for i in range(n_ex):
    examples.append(gen_example_rotated(size=n_side, label=0))
    examples.append(gen_example_rotated(size=n_side, label=1))

y_new = np.array([0,1]*n_ex)
x_new = np.stack(examples)

plt.figure(figsize=(18,4))

n_print = 10 # number of examples to show

ex_indices = np.random.choice(len(y_new), n_print, replace=False)
for i, index in enumerate(ex_indices):
    plt.subplot(1, n_print, i+1, )
    plt.imshow(x_new[index,...], cmap='gray')
    plt.title(f"y = {y_new[index]}")

# %%
plt.figure(figsize=(18,4))

for i, index in enumerate(ex_indices):
    plt.subplot(1, n_print, i+1, )
    plt.imshow(x_new[index,...], cmap='gray')
    plt.title("yhat =  %0.2f" % model_conv.predict(x_new[index].reshape((1,30,30,1))))
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
new_test_score = model_conv.evaluate(x_new[...,np.newaxis], y_new)[1]
# Out:
# 4/4 [==============================] - 0s 8ms/step - loss: 7.3983e-08 - accuracy: 1.0000

# %% [markdown]
# Visualizing what the network learns
# -----------------------------------

# %%
from ipywidgets import interactive
from ipywidgets import Layout
import ipywidgets as widgets

def plot_layer(test_idx, layer_idx):
  convout1_f = K.function(model_conv.inputs, [model_conv.layers[layer_idx].output])
  convolutions = np.squeeze(convout1_f(x[test_idx].reshape((1,30,30,1))))
  if (len(convolutions.shape)) > 1:
    m = convolutions.shape[2]
    n = int(np.ceil(np.sqrt(m)))

    # Visualization of each filter of the layer
    fig = plt.figure(figsize=(15,12))
    print(model_conv.layers[layer_idx].name)
    for i in range(m):
        ax = fig.add_subplot(n,n,i+1)
        ax.imshow(convolutions[:,:,i], cmap='gray')
        ax.set_title(i)
  else:
    print(model_conv.layers[layer_idx].name)
    plt.imshow(convolutions.reshape(1, convolutions.shape[0]), cmap='gray');
    plt.yticks([])
    plt.xticks(range(convolutions.shape[0]))

  plt.show();

style = {'description_width': 'initial'}
layout = Layout(width="800px")
test_idx = widgets.IntSlider(min=0, max=len(x)-1, value=0, style=style, layout=layout)
layer_idx = widgets.IntSlider(min=0, max=len(model_conv.layers)-2, value=0, style=style, layout=layout)
interactive(plot_layer, test_idx=test_idx, layer_idx=layer_idx)
# Out:
# interactive(children=(IntSlider(value=0, description='test_idx', layout=Layout(width='800px'), max=999, style=…
